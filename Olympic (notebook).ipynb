# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
#import plotly.express as px

# %%
olympic = pd.read_csv(r'D:\Backup\TIT\D4E\Project\Olympic\athlete_events.csv')
noc = pd.read_csv(r'D:\Backup\TIT\D4E\Project\Olympic\noc_regions.csv')

# %%
noc
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
olympic
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %% [markdown]
# # Mean H/W WINTER

# %%
count_winter = olympic[olympic['Season'] == 'Winter'].Sex.value_counts()

winter_mean_hw = olympic[olympic['Season'] == 'Winter'].groupby(['Sex']).mean()[['Height', 'Weight', 'Age']]

print(f'Mean H/W WINTER: \n {winter_mean_hw}')

print(f'COUNT:\n {count_winter}')
# Out:
# Mean H/W WINTER:
#           Height     Weight        Age
# Sex
# F    166.528250  59.755156  24.014398
# M    178.668699  76.357058  25.504261
# COUNT:
#  M    33485
# F    15079
# Name: Sex, dtype: int64

# %% [markdown]
# # Mean H/W SUMMER

# %%
count_summer = olympic[olympic['Season'] == 'Summer'].Sex.value_counts()

summer_mean_hw = olympic[olympic['Season'] == 'Summer'].groupby(['Sex']).mean()[['Height', 'Weight', 'Age']]

print(f'Mean H/W SUMMER: \n {summer_mean_hw}')

print(f'COUNT:\n {count_summer}')
# Out:
# Mean H/W SUMMER:
#           Height     Weight        Age
# Sex
# F    168.169025  60.087644  23.660997
# M    178.901874  75.604195  26.443944
# COUNT:
#  M    163109
# F     59443
# Name: Sex, dtype: int64

# %% [markdown]
# # Mean H/W GOLD MEDAL

# %%
count_gold_medal = olympic[olympic['Medal'] == 'Gold'].Sex.value_counts()

gold_medal_mean_hw = olympic[olympic['Medal'] == 'Gold'].groupby(['Sex']).mean()[['Height', 'Weight', 'Age']]

print(f'Mean H/W GOLD MEDAL: \n {gold_medal_mean_hw}')

print(f'COUNT:\n {count_gold_medal}')
# Out:
# Mean H/W GOLD MEDAL:
#           Height     Weight        Age
# Sex
# F    170.693872  63.463486  24.372596
# M    181.468568  79.588895  26.504641
# COUNT:
#  M    9625
# F    3747
# Name: Sex, dtype: int64

# %% [markdown]
# # Mean H/W OLYMPIC

# %%
olympic_mean_hw = olympic.groupby(['Sex']).mean()[['Height', 'Weight', 'Age']]

print(f'Mean H/W OLYMPIC: \n {olympic_mean_hw}')
# Out:
# Mean H/W OLYMPIC:
#           Height     Weight        Age
# Sex
# F    167.839740  60.021252  23.732881
# M    178.858463  75.743677  26.277562

# %% [markdown]
# # JOIN DATASET

# %%
join = olympic.join(noc.set_index('NOC'), on='NOC')[olympic['Medal'] == 'Gold']

#olympic[olympic['Medal'] == 'Gold'].sort_values(by=['Age'], ascending=False).head(10)

join
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
#                   Team  NOC        Games  Year  Season         City  \
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris
# 42             Finland  FIN  1948 Summer  1948  Summer       London
# 44             Finland  FIN  1948 Summer  1948  Summer       London
# 48             Finland  FIN  1948 Summer  1948  Summer       London
# 60              Norway  NOR  1992 Winter  1992  Winter  Albertville
# ...                ...  ...          ...   ...     ...          ...
# 270981         Georgia  GEO  2004 Summer  2004  Summer       Athina
# 271009         Germany  GER  2004 Summer  2004  Summer       Athina
# 271016     Netherlands  NED  1996 Summer  1996  Summer      Atlanta
# 271049     Netherlands  NED  1996 Summer  1996  Summer      Atlanta
# 271076    Soviet Union  URS  1952 Summer  1952  Summer     Helsinki
#
#                 Sport                             Event Medal       region  \
# 3          Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold      Denmark
# 42         Gymnastics  Gymnastics Men's Team All-Around  Gold      Finland
# 44         Gymnastics      Gymnastics Men's Horse Vault  Gold      Finland
# 48         Gymnastics  Gymnastics Men's Pommelled Horse  Gold      Finland
# 60      Alpine Skiing       Alpine Skiing Men's Super G  Gold       Norway
# ...               ...                               ...   ...          ...
# 270981           Judo           Judo Men's Middleweight  Gold      Georgia
# 271009         Hockey             Hockey Women's Hockey  Gold      Germany
# 271016     Volleyball       Volleyball Men's Volleyball  Gold  Netherlands
# 271049         Rowing         Rowing Men's Coxed Eights  Gold  Netherlands
# 271076      Athletics        Athletics Women's Shot Put  Gold       Russia
#
#        notes
# 3        NaN
# 42       NaN
# 44       NaN
# 48       NaN
# 60       NaN
# ...      ...
# 270981   NaN
# 271009   NaN
# 271016   NaN
# 271049   NaN
# 271076   NaN
#
# [13372 rows x 17 columns]

# %% [markdown]
# # Team - Pie Chart (Gold Medal)

# %%
gold_pie = olympic[olympic['Medal'] == 'Gold'].Team.value_counts()

plt.pie(gold_pie)
# Out:
# ([<matplotlib.patches.Wedge at 0x17a7394b3a0>,
#   <matplotlib.patches.Wedge at 0x17a7394b880>,
#   <matplotlib.patches.Wedge at 0x17a7394bd00>,
#   <matplotlib.patches.Wedge at 0x17a7395b1c0>,
#   <matplotlib.patches.Wedge at 0x17a7395b640>,
#   <matplotlib.patches.Wedge at 0x17a7395bac0>,
#   <matplotlib.patches.Wedge at 0x17a7395bf40>,
#   <matplotlib.patches.Wedge at 0x17a73967400>,
#   <matplotlib.patches.Wedge at 0x17a73967880>,
#   <matplotlib.patches.Wedge at 0x17a73967d00>,
#   <matplotlib.patches.Wedge at 0x17a737cddc0>,
#   <matplotlib.patches.Wedge at 0x17a73974610>,
#   <matplotlib.patches.Wedge at 0x17a73974a90>,
#   <matplotlib.patches.Wedge at 0x17a73974f10>,
#   <matplotlib.patches.Wedge at 0x17a739803d0>,
#   <matplotlib.patches.Wedge at 0x17a73980850>,
#   <matplotlib.patches.Wedge at 0x17a73980cd0>,
#   <matplotlib.patches.Wedge at 0x17a7398f190>,
#   <matplotlib.patches.Wedge at 0x17a7398f610>,
#   <matplotlib.patches.Wedge at 0x17a7398fa90>,
#   <matplotlib.patches.Wedge at 0x17a7398ff10>,
#   <matplotlib.patches.Wedge at 0x17a7399b3d0>,
#   <matplotlib.patches.Wedge at 0x17a7399b850>,
#   <matplotlib.patches.Wedge at 0x17a7399bcd0>,
#   <matplotlib.patches.Wedge at 0x17a739a9190>,
#   <matplotlib.patches.Wedge at 0x17a739a9610>,
#   <matplotlib.patches.Wedge at 0x17a739a9a90>,
#   <matplotlib.patches.Wedge at 0x17a739a9f10>,
#   <matplotlib.patches.Wedge at 0x17a739b63d0>,
#   <matplotlib.patches.Wedge at 0x17a739b6850>,
#   <matplotlib.patches.Wedge at 0x17a739b6cd0>,
#   <matplotlib.patches.Wedge at 0x17a739c4190>,
#   <matplotlib.patches.Wedge at 0x17a739c4610>,
#   <matplotlib.patches.Wedge at 0x17a739c4a90>,
#   <matplotlib.patches.Wedge at 0x17a739c4f10>,
#   <matplotlib.patches.Wedge at 0x17a739d13d0>,
#   <matplotlib.patches.Wedge at 0x17a739d1850>,
#   <matplotlib.patches.Wedge at 0x17a739d1cd0>,
#   <matplotlib.patches.Wedge at 0x17a739df190>,
#   <matplotlib.patches.Wedge at 0x17a739df610>,
#   <matplotlib.patches.Wedge at 0x17a739dfa90>,
#   <matplotlib.patches.Wedge at 0x17a739dff10>,
#   <matplotlib.patches.Wedge at 0x17a739ec3d0>,
#   <matplotlib.patches.Wedge at 0x17a739ec850>,
#   <matplotlib.patches.Wedge at 0x17a739eccd0>,
#   <matplotlib.patches.Wedge at 0x17a739fb190>,
#   <matplotlib.patches.Wedge at 0x17a739fb610>,
#   <matplotlib.patches.Wedge at 0x17a739fba90>,
#   <matplotlib.patches.Wedge at 0x17a739fbf10>,
#   <matplotlib.patches.Wedge at 0x17a73a073d0>,
#   <matplotlib.patches.Wedge at 0x17a73a07850>,
#   <matplotlib.patches.Wedge at 0x17a73a07cd0>,
#   <matplotlib.patches.Wedge at 0x17a73a15190>,
#   <matplotlib.patches.Wedge at 0x17a73a15610>,
#   <matplotlib.patches.Wedge at 0x17a73a15a90>,
#   <matplotlib.patches.Wedge at 0x17a73a15f10>,
#   <matplotlib.patches.Wedge at 0x17a73a223d0>,
#   <matplotlib.patches.Wedge at 0x17a73a22850>,
#   <matplotlib.patches.Wedge at 0x17a73a22cd0>,
#   <matplotlib.patches.Wedge at 0x17a73a31190>,
#   <matplotlib.patches.Wedge at 0x17a73a31610>,
#   <matplotlib.patches.Wedge at 0x17a73a31a90>,
#   <matplotlib.patches.Wedge at 0x17a73a31f10>,
#   <matplotlib.patches.Wedge at 0x17a73a3c3d0>,
#   <matplotlib.patches.Wedge at 0x17a73a3c850>,
#   <matplotlib.patches.Wedge at 0x17a73a3ccd0>,
#   <matplotlib.patches.Wedge at 0x17a73a4a190>,
#   <matplotlib.patches.Wedge at 0x17a73a4a610>,
#   <matplotlib.patches.Wedge at 0x17a73a4aa90>,
#   <matplotlib.patches.Wedge at 0x17a73a4af10>,
#   <matplotlib.patches.Wedge at 0x17a73a563d0>,
#   <matplotlib.patches.Wedge at 0x17a73a56850>,
#   <matplotlib.patches.Wedge at 0x17a73a56cd0>,
#   <matplotlib.patches.Wedge at 0x17a73a64190>,
#   <matplotlib.patches.Wedge at 0x17a73a64610>,
#   <matplotlib.patches.Wedge at 0x17a73a64a90>,
#   <matplotlib.patches.Wedge at 0x17a73a64f10>,
#   <matplotlib.patches.Wedge at 0x17a73a723d0>,
#   <matplotlib.patches.Wedge at 0x17a73a72850>,
#   <matplotlib.patches.Wedge at 0x17a73a72cd0>,
#   <matplotlib.patches.Wedge at 0x17a73a80190>,
#   <matplotlib.patches.Wedge at 0x17a73a80610>,
#   <matplotlib.patches.Wedge at 0x17a73a80a90>,
#   <matplotlib.patches.Wedge at 0x17a73a80f10>,
#   <matplotlib.patches.Wedge at 0x17a73a8d3d0>,
#   <matplotlib.patches.Wedge at 0x17a73a8d850>,
#   <matplotlib.patches.Wedge at 0x17a73a8dcd0>,
#   <matplotlib.patches.Wedge at 0x17a73a9b190>,
#   <matplotlib.patches.Wedge at 0x17a73a9b610>,
#   <matplotlib.patches.Wedge at 0x17a73a9ba90>,
#   <matplotlib.patches.Wedge at 0x17a73a9bf10>,
#   <matplotlib.patches.Wedge at 0x17a73aa63d0>,
#   <matplotlib.patches.Wedge at 0x17a73aa6850>,
#   <matplotlib.patches.Wedge at 0x17a73aa6d00>,
#   <matplotlib.patches.Wedge at 0x17a73ab51c0>,
#   <matplotlib.patches.Wedge at 0x17a73ab5640>,
#   <matplotlib.patches.Wedge at 0x17a73ab5ac0>,
#   <matplotlib.patches.Wedge at 0x17a73ab5f40>,
#   <matplotlib.patches.Wedge at 0x17a73ac2400>,
#   <matplotlib.patches.Wedge at 0x17a73ac2880>,
#   <matplotlib.patches.Wedge at 0x17a73ac2d00>,
#   <matplotlib.patches.Wedge at 0x17a73ad01c0>,
#   <matplotlib.patches.Wedge at 0x17a73ad0640>,
#   <matplotlib.patches.Wedge at 0x17a73ad0ac0>,
#   <matplotlib.patches.Wedge at 0x17a73ad0f40>,
#   <matplotlib.patches.Wedge at 0x17a73adc400>,
#   <matplotlib.patches.Wedge at 0x17a73adc880>,
#   <matplotlib.patches.Wedge at 0x17a73adcd00>,
#   <matplotlib.patches.Wedge at 0x17a73aeb1c0>,
#   <matplotlib.patches.Wedge at 0x17a73aeb640>,
#   <matplotlib.patches.Wedge at 0x17a73aebac0>,
#   <matplotlib.patches.Wedge at 0x17a73aebf40>,
#   <matplotlib.patches.Wedge at 0x17a73af7400>,
#   <matplotlib.patches.Wedge at 0x17a73af7880>,
#   <matplotlib.patches.Wedge at 0x17a73af7d00>,
#   <matplotlib.patches.Wedge at 0x17a73b051c0>,
#   <matplotlib.patches.Wedge at 0x17a73b05640>,
#   <matplotlib.patches.Wedge at 0x17a73b05ac0>,
#   <matplotlib.patches.Wedge at 0x17a73b05f40>,
#   <matplotlib.patches.Wedge at 0x17a73b11400>,
#   <matplotlib.patches.Wedge at 0x17a73b11880>,
#   <matplotlib.patches.Wedge at 0x17a73b11d00>,
#   <matplotlib.patches.Wedge at 0x17a73b211c0>,
#   <matplotlib.patches.Wedge at 0x17a73b21640>,
#   <matplotlib.patches.Wedge at 0x17a73b21ac0>,
#   <matplotlib.patches.Wedge at 0x17a73b21f40>,
#   <matplotlib.patches.Wedge at 0x17a73b2e400>,
#   <matplotlib.patches.Wedge at 0x17a73b2e880>,
#   <matplotlib.patches.Wedge at 0x17a73b2ed00>,
#   <matplotlib.patches.Wedge at 0x17a74cfc1c0>,
#   <matplotlib.patches.Wedge at 0x17a74cfc640>,
#   <matplotlib.patches.Wedge at 0x17a74cfcac0>,
#   <matplotlib.patches.Wedge at 0x17a74cfcf40>,
#   <matplotlib.patches.Wedge at 0x17a74d07400>,
#   <matplotlib.patches.Wedge at 0x17a74d07880>,
#   <matplotlib.patches.Wedge at 0x17a74d07d00>,
#   <matplotlib.patches.Wedge at 0x17a74d151c0>,
#   <matplotlib.patches.Wedge at 0x17a74d15640>,
#   <matplotlib.patches.Wedge at 0x17a74d15ac0>,
#   <matplotlib.patches.Wedge at 0x17a74d15f40>,
#   <matplotlib.patches.Wedge at 0x17a74d23400>,
#   <matplotlib.patches.Wedge at 0x17a74d23880>,
#   <matplotlib.patches.Wedge at 0x17a74d23d00>,
#   <matplotlib.patches.Wedge at 0x17a74d311c0>,
#   <matplotlib.patches.Wedge at 0x17a74d31640>,
#   <matplotlib.patches.Wedge at 0x17a74d31ac0>,
#   <matplotlib.patches.Wedge at 0x17a74d31f40>,
#   <matplotlib.patches.Wedge at 0x17a74d3d400>,
#   <matplotlib.patches.Wedge at 0x17a74d3d880>,
#   <matplotlib.patches.Wedge at 0x17a74d3dd00>,
#   <matplotlib.patches.Wedge at 0x17a74d4b1c0>,
#   <matplotlib.patches.Wedge at 0x17a74d4b640>,
#   <matplotlib.patches.Wedge at 0x17a74d4bac0>,
#   <matplotlib.patches.Wedge at 0x17a74d4bf40>,
#   <matplotlib.patches.Wedge at 0x17a74d58400>,
#   <matplotlib.patches.Wedge at 0x17a74d588b0>,
#   <matplotlib.patches.Wedge at 0x17a74d58d30>,
#   <matplotlib.patches.Wedge at 0x17a74d661f0>,
#   <matplotlib.patches.Wedge at 0x17a74d66670>,
#   <matplotlib.patches.Wedge at 0x17a74d66af0>,
#   <matplotlib.patches.Wedge at 0x17a74d66f70>,
#   <matplotlib.patches.Wedge at 0x17a74d72430>,
#   <matplotlib.patches.Wedge at 0x17a74d728b0>,
#   <matplotlib.patches.Wedge at 0x17a74d72d30>,
#   <matplotlib.patches.Wedge at 0x17a74d81220>,
#   <matplotlib.patches.Wedge at 0x17a74d816a0>,
#   <matplotlib.patches.Wedge at 0x17a74d81b20>,
#   <matplotlib.patches.Wedge at 0x17a74d81fa0>,
#   <matplotlib.patches.Wedge at 0x17a74d8e460>,
#   <matplotlib.patches.Wedge at 0x17a74d8e8e0>,
#   <matplotlib.patches.Wedge at 0x17a74d8ed60>,
#   <matplotlib.patches.Wedge at 0x17a74d9c220>,
#   <matplotlib.patches.Wedge at 0x17a74d9c6a0>,
#   <matplotlib.patches.Wedge at 0x17a74d9cb20>,
#   <matplotlib.patches.Wedge at 0x17a74d9cfa0>,
#   <matplotlib.patches.Wedge at 0x17a74da8460>,
#   <matplotlib.patches.Wedge at 0x17a74da88e0>,
#   <matplotlib.patches.Wedge at 0x17a74da8d60>,
#   <matplotlib.patches.Wedge at 0x17a74db6220>,
#   <matplotlib.patches.Wedge at 0x17a74db66a0>,
#   <matplotlib.patches.Wedge at 0x17a74db6b20>,
#   <matplotlib.patches.Wedge at 0x17a74db6fa0>,
#   <matplotlib.patches.Wedge at 0x17a74dc3460>,
#   <matplotlib.patches.Wedge at 0x17a74dc38e0>,
#   <matplotlib.patches.Wedge at 0x17a74dc3d60>,
#   <matplotlib.patches.Wedge at 0x17a74dd2220>,
#   <matplotlib.patches.Wedge at 0x17a74dd26a0>,
#   <matplotlib.patches.Wedge at 0x17a74dd2b20>,
#   <matplotlib.patches.Wedge at 0x17a74dd2fa0>,
#   <matplotlib.patches.Wedge at 0x17a74dde460>,
#   <matplotlib.patches.Wedge at 0x17a74dde8e0>,
#   <matplotlib.patches.Wedge at 0x17a74dded60>,
#   <matplotlib.patches.Wedge at 0x17a74deb220>,
#   <matplotlib.patches.Wedge at 0x17a74deb6a0>,
#   <matplotlib.patches.Wedge at 0x17a74debb20>,
#   <matplotlib.patches.Wedge at 0x17a74debfa0>,
#   <matplotlib.patches.Wedge at 0x17a74df8490>,
#   <matplotlib.patches.Wedge at 0x17a74df8910>,
#   <matplotlib.patches.Wedge at 0x17a74df8d90>,
#   <matplotlib.patches.Wedge at 0x17a74e05250>,
#   <matplotlib.patches.Wedge at 0x17a74e056d0>,
#   <matplotlib.patches.Wedge at 0x17a74e05b50>,
#   <matplotlib.patches.Wedge at 0x17a74e05fd0>,
#   <matplotlib.patches.Wedge at 0x17a74e13490>,
#   <matplotlib.patches.Wedge at 0x17a74e13910>,
#   <matplotlib.patches.Wedge at 0x17a74e13d90>,
#   <matplotlib.patches.Wedge at 0x17a74e20250>,
#   <matplotlib.patches.Wedge at 0x17a74e206d0>,
#   <matplotlib.patches.Wedge at 0x17a74e20b50>,
#   <matplotlib.patches.Wedge at 0x17a74e20fd0>,
#   <matplotlib.patches.Wedge at 0x17a74e2d490>,
#   <matplotlib.patches.Wedge at 0x17a74e2d910>,
#   <matplotlib.patches.Wedge at 0x17a74e2dd90>,
#   <matplotlib.patches.Wedge at 0x17a74e3b250>,
#   <matplotlib.patches.Wedge at 0x17a74e3b6d0>,
#   <matplotlib.patches.Wedge at 0x17a74e3bb50>,
#   <matplotlib.patches.Wedge at 0x17a74e3bfd0>,
#   <matplotlib.patches.Wedge at 0x17a74e49490>,
#   <matplotlib.patches.Wedge at 0x17a74e49910>,
#   <matplotlib.patches.Wedge at 0x17a74e49d90>,
#   <matplotlib.patches.Wedge at 0x17a74e56250>,
#   <matplotlib.patches.Wedge at 0x17a74e566d0>,
#   <matplotlib.patches.Wedge at 0x17a74e56b50>,
#   <matplotlib.patches.Wedge at 0x17a74e56fd0>,
#   <matplotlib.patches.Wedge at 0x17a74e64490>,
#   <matplotlib.patches.Wedge at 0x17a74e64910>,
#   <matplotlib.patches.Wedge at 0x17a74e64d90>,
#   <matplotlib.patches.Wedge at 0x17a74e70250>,
#   <matplotlib.patches.Wedge at 0x17a74e706d0>,
#   <matplotlib.patches.Wedge at 0x17a74e70b50>,
#   <matplotlib.patches.Wedge at 0x17a74e70fd0>,
#   <matplotlib.patches.Wedge at 0x17a74e7d490>,
#   <matplotlib.patches.Wedge at 0x17a74e7d910>,
#   <matplotlib.patches.Wedge at 0x17a74e7dd90>,
#   <matplotlib.patches.Wedge at 0x17a74e8a250>,
#   <matplotlib.patches.Wedge at 0x17a74e8a6d0>,
#   <matplotlib.patches.Wedge at 0x17a74e8ab50>,
#   <matplotlib.patches.Wedge at 0x17a74e8afd0>,
#   <matplotlib.patches.Wedge at 0x17a74e99490>,
#   <matplotlib.patches.Wedge at 0x17a74e99940>,
#   <matplotlib.patches.Wedge at 0x17a74e99dc0>,
#   <matplotlib.patches.Wedge at 0x17a74ea6280>],
#  [Text(0.9193625627476768, 0.603963970960209, ''),
#   Text(0.17498715028189482, 1.0859924020158804, ''),
#   Text(-0.27036366497948033, 1.0662567648830479, ''),
#   Text(-0.5594472095506774, 0.9471107747913972, ''),
#   Text(-0.7745212122854447, 0.7810997962615823, ''),
#   Text(-0.9315144536466908, 0.5850477097188804, ''),
#   Text(-1.0340835366581111, 0.37506164721636515, ''),
#   Text(-1.0891617910985008, 0.15403438840436323, ''),
#   Text(-1.0980110724389087, -0.06611871748270597, ''),
#   Text(-1.0668890060579466, -0.267857889099215, ''),
#   Text(-1.004998077482521, -0.4471899643959344, ''),
#   Text(-0.9170857489830243, -0.6074156147254083, ''),
#   Text(-0.8140149656224581, -0.7398510902490234, ''),
#   Text(-0.7006007031234072, -0.848032225085219, ''),
#   Text(-0.5797860642265964, -0.9347984380221402, ''),
#   Text(-0.46060783183628917, -0.9989196290248145, ''),
#   Text(-0.35066579814458354, -1.0426089861552232, ''),
#   Text(-0.24901827545595118, -1.0714429049132503, ''),
#   Text(-0.15608119323069208, -1.0888703601070622, ''),
#   Text(-0.07076143493055034, -1.0977216492930117, ''),
#   Text(0.01317973476761887, -1.0999210401621815, ''),
#   Text(0.09472706920538845, -1.0959136746841687, ''),
#   Text(0.1714142480305352, -1.0865620808642857, ''),
#   Text(0.24297304141725581, -1.0728299497797629, ''),
gold_pie.head(30)
# Out:
# United States    2474
# Soviet Union     1058
# Germany           679
# Italy             535
# Great Britain     519
# France            455
# Sweden            451
# Hungary           432
# Canada            422
# East Germany      369
# Russia            366
# Australia         342
# China             308
# Norway            299
# Netherlands       277
# Japan             247
# South Korea       211
# Finland           198
# Denmark           168
# Cuba              164
# Romania           161
# West Germany      155
# Switzerland       144
# India             138
# Yugoslavia        130
# Unified Team      123
# Poland            117
# Spain             108
# Brazil            103
# Austria            95
# Name: Team, dtype: int64

# %%
gold_pie.sum()
# Out:
# 13372

# %% [markdown]
# # USA - Gold Medal count

# %%
usa = olympic[olympic['Medal'] == 'Gold'][olympic['Team'] == 'United States']

usa.Sport.value_counts().head(10)
# Out:
# C:\Users\Kiet\AppData\Local\Temp/ipykernel_12096/4275124142.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   usa = olympic[olympic['Medal'] == 'Gold'][olympic['Team'] == 'United States']
# Swimming      645
# Athletics     537
# Basketball    281
# Rowing        160
# Shooting      117
# Football       66
# Ice Hockey     56
# Gymnastics     55
# Wrestling      52
# Boxing         50
# Name: Sport, dtype: int64

# %% [markdown]
# # Country_Basketball - Gold Medal count

# %%
country = olympic[olympic['Medal'] == 'Gold'][olympic['Sport'] == 'Basketball']

country.Team.value_counts()
# Out:
# C:\Users\Kiet\AppData\Local\Temp/ipykernel_12096/263723201.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   country = olympic[olympic['Medal'] == 'Gold'][olympic['Sport'] == 'Basketball']
# United States    281
# Soviet Union      48
# Yugoslavia        12
# Argentina         12
# Unified Team      12
# Name: Team, dtype: int64

# %% [markdown]
# # Country_Swimming - Gold Medal count

# %%
ct2 = olympic[olympic['Medal'] == 'Gold'][olympic['Sport'] == 'Swimming']

ct2.Team.value_counts().head()
# Out:
# C:\Users\Kiet\AppData\Local\Temp/ipykernel_12096/4226728564.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ct2 = olympic[olympic['Medal'] == 'Gold'][olympic['Sport'] == 'Swimming']
# United States    645
# Australia        118
# East Germany      62
# Hungary           36
# Netherlands       30
# Name: Team, dtype: int64

# %% [markdown]
# # Russia - Gold Medal count

# %%
rus = join[join['Medal'] == 'Gold'][join['region'] == 'Russia']

rus.Sport.value_counts().head(10)
# Out:
# Gymnastics              176
# Ice Hockey              153
# Athletics               124
# Fencing                 101
# Wrestling                97
# Handball                 97
# Volleyball               93
# Cross Country Skiing     73
# Basketball               60
# Canoeing                 59
# Name: Sport, dtype: int64

# %% [markdown]
# # VIE - Olympic

# %%
vie_olympic = olympic.join(noc.set_index('NOC'), on='NOC')[olympic['NOC'] == 'VIE']

# %%
vie_mean_hw = vie_olympic.groupby(['Sex']).mean()[['Height', 'Weight', 'Age']]

count_vie = olympic[olympic['NOC'] == 'VIE'].Sex.value_counts()

print(f'Mean H/W VIE-OLYMPIC: \n {vie_mean_hw}')

print(f'COUNT:\n {count_vie}')
# Out:
# Mean H/W VIE-OLYMPIC:
#           Height     Weight        Age
# Sex
# F    161.463768  52.642857  21.716216
# M    168.428571  62.038961  26.425000
# COUNT:
#  M    80
# F    74
# Name: Sex, dtype: int64
